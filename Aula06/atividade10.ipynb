# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('car_prices.csv')
data = df.copy()

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
data = data.dropna()

# %%
data.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  472325.000000  472325.000000  472325.000000  472325.000000
# mean     2010.210980      30.774177   66701.732040   13837.058964
# std         3.822151      13.286866   51939.586894    9532.229273
# min      1990.000000       1.000000       1.000000      25.000000
# 25%      2008.000000      24.000000   28137.000000    7425.000000
# 50%      2012.000000      35.000000   51085.000000   12300.000000
# 75%      2013.000000      41.000000   96590.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  472325.000000
# mean    13690.512058
# std      9613.033738
# min         1.000000
# 25%      7200.000000
# 50%     12200.000000
# 75%     18200.000000
# max    230000.000000

# %%
data_a= data.drop(["trim","vin","state","condition","odometer","interior","seller","mmr"],axis=1)

# %%
data_a
# Out:
#         year    make                model       body transmission  color  \
# 0       2015     Kia              Sorento        SUV    automatic  white
# 1       2015     Kia              Sorento        SUV    automatic  white
# 2       2014     BMW             3 Series      Sedan    automatic   gray
# 3       2015   Volvo                  S60      Sedan    automatic  white
# 4       2014     BMW  6 Series Gran Coupe      Sedan    automatic   gray
# ...      ...     ...                  ...        ...          ...    ...
# 558831  2011     BMW             5 Series      Sedan    automatic  white
# 558833  2012     Ram                 2500   Crew Cab    automatic  white
# 558834  2012     BMW                   X5        SUV    automatic  black
# 558835  2015  Nissan               Altima      sedan    automatic  white
# 558836  2014    Ford                F-150  SuperCrew    automatic   gray
#
#         sellingprice                                 saledate
# ...

# %%
data_filter = data_a.loc[lambda table:table['year']==2010]

# %%
# Contando os valores de 'make'
data_counts = data_filter['make'].value_counts().reset_index()

# %%
data_counts
# Out:
#              make  count
# 0            Ford   3534
# 1       Chevrolet   3347
# 2           Dodge   2421
# 3          Toyota   1991
# 4           Honda   1313
# 5          Nissan   1271
# 6         Hyundai    740
# 7   Mercedes-Benz    738
# 8            Jeep    730
# 9        Chrysler    724
# 10            Kia    621
# 11            GMC    587
# 12          Mazda    551
# 13     Volkswagen    532
# 14            BMW    491
# 15          Lexus    483
# 16       Cadillac    331
# 17          Buick    253
# 18           Audi    236
# 19          Acura    201
# 20        Lincoln    186
# 21     Mitsubishi    165
# 22         Subaru    165
# 23           MINI    147
# 24        Mercury    137
# 25          Volvo    135
# 26       Infiniti    135
# 27     Land Rover    111
# 28          Scion     95
# 29        Pontiac     65
# 30         Suzuki     64
# 31        Porsche     44
# 32         Jaguar     41
# 33           Saab      9
# 34          smart      6
# 35        Ferrari      6
# ...

# %%
top_car= data_counts.sort_values('count',ascending=False).head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(20,5))

ax.bar_label(ax.bar(top_car["make"],top_car["count"]),padding=0.3)
sns.barplot(data= top_car, x=top_car["make"], y=top_car["count"], palette="bright")
ax.set_title("Top 5 Sales Car in 10s per Make")
ax.set_xlabel("Make")
ax.set_ylabel("Number of Sales")
ax.set_ylim(0, top_car["count"].max() * 1.1)
plt.show()
# Out:
# C:\Users\D18_11\AppData\Local\Temp\ipykernel_27556\2887137852.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= top_car, x=top_car["make"], y=top_car["count"], palette="bright")

# %% [markdown]
# 2) Gráfico

# %%
data_a
# Out:
#         year    make                model       body transmission  color  \
# 0       2015     Kia              Sorento        SUV    automatic  white
# 1       2015     Kia              Sorento        SUV    automatic  white
# 2       2014     BMW             3 Series      Sedan    automatic   gray
# 3       2015   Volvo                  S60      Sedan    automatic  white
# 4       2014     BMW  6 Series Gran Coupe      Sedan    automatic   gray
# ...      ...     ...                  ...        ...          ...    ...
# 558831  2011     BMW             5 Series      Sedan    automatic  white
# 558833  2012     Ram                 2500   Crew Cab    automatic  white
# 558834  2012     BMW                   X5        SUV    automatic  black
# 558835  2015  Nissan               Altima      sedan    automatic  white
# 558836  2014    Ford                F-150  SuperCrew    automatic   gray
#
#         sellingprice                                 saledate
# ...

# %%
## converter valor para maiusculo
data_a['body'] = [value.upper() for value in data_a['body']]

# %%
data_a
# Out:
#         year    make                model       body transmission  color  \
# 0       2015     Kia              Sorento        SUV    automatic  white
# 1       2015     Kia              Sorento        SUV    automatic  white
# 2       2014     BMW             3 Series      SEDAN    automatic   gray
# 3       2015   Volvo                  S60      SEDAN    automatic  white
# 4       2014     BMW  6 Series Gran Coupe      SEDAN    automatic   gray
# ...      ...     ...                  ...        ...          ...    ...
# 558831  2011     BMW             5 Series      SEDAN    automatic  white
# 558833  2012     Ram                 2500   CREW CAB    automatic  white
# 558834  2012     BMW                   X5        SUV    automatic  black
# 558835  2015  Nissan               Altima      SEDAN    automatic  white
# 558836  2014    Ford                F-150  SUPERCREW    automatic   gray
#
#         sellingprice                                 saledate
# ...

# %%
first_make =data_counts['make'][0]

# %%
data_filter_body = data_a.loc[(data_a['year']==2010)&(data_a['make'] == first_make)]

# %%
data_counts_body = data_filter_body['body'].value_counts().reset_index()

# %%
data_counts_body
# Out:
#             body  count
# 0      SUPERCREW    840
# 1            SUV    793
# 2          SEDAN    669
# 3       SUPERCAB    450
# 4          COUPE    167
# 5       CREW CAB    151
# 6        MINIVAN    138
# 7    REGULAR CAB    114
# 8          WAGON     91
# 9    CONVERTIBLE     70
# 10           VAN     41
# 11  E-SERIES VAN     10

# %%
top_body = data_counts_body.sort_values('count',ascending=False).head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(20,5))

ax.bar_label(ax.bar(top_body["body"],top_body["count"]),padding=0.3)
sns.barplot(data= top_body, x=top_body["body"], y=top_body["count"], palette="bright")
ax.set_title(f'Top 3 Sales Car per Body in 10s by {first_make}')
ax.set_xlabel("Body")
ax.set_ylabel("Number of Sales Car with that Body")
ax.set_ylim(0, top_body["count"].max() * 1.1)
plt.show()
# Out:
# C:\Users\D18_11\AppData\Local\Temp\ipykernel_27556\3577295067.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= top_body, x=top_body["body"], y=top_body["count"], palette="bright")
